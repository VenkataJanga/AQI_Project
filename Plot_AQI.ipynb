# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkataJanga/AQI_Project/blob/master/Plot_AQI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt


# load the file and Preprocessing for AQI2013.csv
def avg_data_aqi_2013():
  average = []
  for rows in pd.read_csv('/content/Data/AQI/aqi2013.csv',chunksize=24):
    data =[]
    var_val = 0
    avg = 0.0
    df = pd.DataFrame(data = rows)
    for index, row in df.iterrows():
      data.append(row['PM2.5'])
    for i in data:
      if type(i) is float or type(i) is int:
        var_val = var_val + i
      elif type(i) is str:
        if i!='NoData' and  i!='---' and  i!='PwrFail' and  i!='InVld':
          var_val = var_val + float(i)
    avg = var_val/24
    average.append(avg)
  return average
# load the file and Preprocessing for AQI2013.csv
def avg_data_aqi_2014():
  average =[]
  for rows in pd.read_csv('/content/Data/AQI/aqi2014.csv',chunksize=24):
    data =[]
    add_var =0
    avg = 0.0
    df = pd.DataFrame(data = rows)
    for index , row in df.iterrows():
      data.append(row['PM2.5'])
    for i in data:
      if type(i) is float or type(i) is int:
        add_var = add_var + i
      elif type(i) is str:
        if i!='NoData' and  i!='---' and  i!='PwrFail' and  i!='InVld':
           add_var = add_var + float(i)
    avg = add_var/24
    average.append(avg)
  return average

# load the file and Preprocessing for AQI2013.csv
def avg_data_aqi_2015():
  average =[]
  for rows in pd.read_csv('/content/Data/AQI/aqi2015.csv',chunksize=24):
    data =[]
    add_var =0
    avg = 0.0
    df = pd.DataFrame(data = rows)
    for index , row in df.iterrows():
      data.append(row['PM2.5'])
    for i in data:
      if type(i) is float or type(i) is int:
        add_var = add_var + i
      elif type(i) is str:
        if i!='NoData' and  i!='---' and  i!='PwrFail' and  i!='InVld':
           add_var = add_var + float(i)
    avg = add_var/24
    average.append(avg)
  return average

# load the file and Preprocessing for AQI2016.csv
def avg_data_aqi_2016():
  average =[]
  for rows in pd.read_csv('/content/Data/AQI/aqi2016.csv',chunksize=24):
    data =[]
    add_var =0
    avg = 0.0
    df = pd.DataFrame(data = rows)
    for index , row in df.iterrows():
      data.append(row['PM2.5'])
    for i in data:
      if type(i) is float or type(i) is int:
        add_var = add_var + i
      elif type(i) is str:
        if i!='NoData' and  i!='---' and  i!='PwrFail' and  i!='InVld':
           add_var = add_var + float(i)
    avg = add_var/24
    average.append(avg)
  return average



# load the file and Preprocessing for AQI2017.csv
def avg_data_aqi_2017():
  average =[]
  for rows in pd.read_csv('/content/Data/AQI/aqi2017.csv',chunksize=24):
    data =[]
    add_var =0
    avg = 0.0
    df = pd.DataFrame(data = rows)
    for index , row in df.iterrows():
      data.append(row['PM2.5'])
    for i in data:
      if type(i) is float or type(i) is int:
        add_var = add_var + i
      elif type(i) is str:
        if i!='NoData' and  i!='---' and  i!='PwrFail' and  i!='InVld':
           add_var = add_var + float(i)
    avg = add_var/24
    average.append(avg)
  return average


# load the file and Preprocessing for AQI2017.csv
def avg_data_aqi_2018():
  average =[]
  for rows in pd.read_csv('/content/Data/AQI/aqi2018.csv',chunksize=24):
    data =[]
    add_var =0
    avg = 0.0
    df = pd.DataFrame(data = rows)
    for index , row in df.iterrows():
      data.append(row['PM2.5'])
    for i in data:
      if type(i) is float or type(i) is int:
        add_var = add_var + i
      elif type(i) is str:
        if i!='NoData' and  i!='---' and  i!='PwrFail' and  i!='InVld':
           add_var = add_var + float(i)
    avg = add_var/24
    average.append(avg)
  return average

if __name__=="__main__":
  list_avg_aqi_2013 = avg_data_aqi_2013()
  plt.plot(range(0,365), list_avg_aqi_2013, label = '2013-data ')
  list_avg_aqi_2014 = avg_data_aqi_2014()
  plt.plot(range(0,364), list_avg_aqi_2014, label = '2014-data')
  list_avg_aqi_2015 = avg_data_aqi_2015()
  plt.plot(range(0,365), list_avg_aqi_2015, label = '2015-data ')
  list_avg_aqi_2016 = avg_data_aqi_2016()
  plt.plot(range(0,121), list_avg_aqi_2016, label = '2016-data ')
  list_avg_aqi_2017 = avg_data_aqi_2017()
  plt.plot(range(0,365), list_avg_aqi_2017, label = '2017-data ')
  list_avg_aqi_2018 = avg_data_aqi_2018()
  plt.plot(range(0,364), list_avg_aqi_2018, label = '2018-data')
